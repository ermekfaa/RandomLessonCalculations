# %%
import control
import matplotlib.pyplot as plt

# %%
(50*(s+2))/((s)*(s+4)*(s+10)*(s+10))

# %%
numerator = [100, 0]  # 50(s+2) -> 50s +        100
denominator = [1, 14, 140, 400, 0]  # s(s+4)(s+10)^2 -> s^4 + 14s^3 + 140s^2 + 400s

# %%
tf = control.TransferFunction(numerator, denominator)

# Bode grafiği çizdiriliyor
mag, phase, omega = control.bode(tf, dB=True)

# Grafiği göster
plt.show()
